# %% [markdown]
# <a href="https://colab.research.google.com/github/ciavie/ClassMio/blob/main/01IntroductionToProcessControl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> Process Dynamic and Control<br>
# (CHEN 341 and CHEN 441)</center></h1>

# %% [markdown]
# <ol>
# <li> Mathematical modeling of process dynamics </li>
#     <ol>
#         <li> Nonreacting Systems </li>
#         <li> CSTR </li>
#     </ol>
# <li> Transfer functions, </li>
# <li> Dynamic behavior of chemical processes, </li>
# <li> Closed-loop transfer function,</li>
# <li> Stability analysis, </li>
# <li> Frequency response analysis, </li>
# <li> Controller design and tuning, </li>
# <li> laboratory and simulations applications. </li>
# </ol>

# %% [markdown]
# https://www.youtube.com/watch?v=kK_8gvijNPI

# %% [markdown]
# try me
